# %%
from __future__ import division
import json
from pprint import pprint
import pickle
import matplotlib.pyplot as plt
from plotLayer import *
from preprocess import *
import os
import time
import numpy as np
import glob
from scipy import sparse as sp
from skimage.measure import block_reduce
from sklearn.metrics import roc_curve, auc, roc_auc_score, classification_report, precision_recall_curve

from model import *
from keras.backend.tensorflow_backend import set_session

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'


def Classify_Rate(y, y_hat):
    # True Positive (TP): we predict a label of 1 (positive), and the true label is 1.
    TP = np.sum(np.logical_and(y_hat == 1, y == 1))
    # True Negative (TN): we predict a label of 0 (negative), and the true label is 0.
    TN = np.sum(np.logical_and(y_hat == 0, y == 0))
    # False Positive (FP): we predict a label of 1 (positive), but the true label is 0.
    FP = np.sum(np.logical_and(y_hat == 1, y == 0))
    # False Negative (FN): we predict a label of 0 (negative), but the true label is 1.
    FN = np.sum(np.logical_and(y_hat == 0, y == 1))
    return TP, TN, FP, FN


def Predict(model, x, y_threshold=None):
    y_hat = model.predict(x)

    if y_threshold :
        y_hat[y_hat < y_threshold] = 0
        y_hat[y_hat >= y_threshold] = 1
    return y_hat

def PlotROC(y, y_hat):
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(2):
        fpr[i], tpr[i], _ = roc_curve(y, y_hat)
        roc_auc[i] = auc(fpr[i], tpr[i])
    print ("roc_auc_score:%f" %roc_auc_score(y, y_hat))
    plt.figure()
    plt.plot(fpr[1], tpr[1])
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.show()

def PreprocessData(datapath, width=256, channel=6):
    ratio = 1024 // width
    with open(datapath, "rb") as f:
        data = pickle.load(f)
    x = np.heaviside(np.array([map(lambda x: block_reduce(x.toarray(), block_size=(ratio,ratio), func=np.max), d.hL) for d in data]), 0)
    x = np.swapaxes(x, 1, 3)
    y = np.array([d.label for d in data])
    return x, y


if __name__ == "__main__":
    width = 256
    channel = 6
    #classify_weights_path = "Classify_epoch_50_batch_4.hdf5"
    classify_weights_path = "Classify_epoch_100_batch_4.hdf5"


    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
    config.gpu_options.per_process_gpu_memory_fraction = 0.9
    sess = tf.Session(config=config)
    set_session(sess)

    classify_model = Encoder_Classify(input_size=(width,width,6), batch_normal=True)
    classify_model.load_weights(classify_weights_path)

    d0_path = "../Data/1stDataset/d0*"
    false_path = "../Data/1stDataset/false*"
    d0 = np.sort(glob.glob(d0_path))
    f0 = np.sort(glob.glob(false_path))

    y_total = []
    y_hat_total = []
#     301
    for i in range(500,551):
        x1, y1 = PreprocessData(d0[i], width=width, channel=channel)
        x2, y2 = PreprocessData(f0[i], width=width, channel=channel)
        x = np.concatenate((x1, x2), axis=0)
        y = np.concatenate((y1, y2), axis=0)

        y_hat = Predict(classify_model, x)
        y_total += [y]
        y_hat_total += [y_hat]
        print("y_hat mean:%f median:%f" %(np.mean(y_hat), np.median(y_hat)))
        y_hat[y_hat < np.median(y_hat)] = 0
        y_hat[y_hat >= np.median(y_hat)] = 1

        TP, TN, FP, FN = Classify_Rate(y, y_hat)
        print("Sensitive TP/(TP+FN) : %f" %(TP / (TP + FN)))
        print(classification_report(y, y_hat))

    y = np.concatenate(y_total)
    y_hat = np.concatenate(y_hat_total)
    print(y.shape)
    print(y_hat.shape)
    print("y_hat mean:%f median:%f" %(np.mean(y_hat), np.median(y_hat)))
    fp,tp,tr=roc_curve(y,y_hat)
    p,r,tr1=precision_recall_curve(y,y_hat)
    plt.plot(fp,tp,color='darkorange',lw=2,label='ROC curve(area = %0.3f)'%auc(fp,tp))
    plt.xlabel('False positive Rate')
    plt.ylabel('True positive Rate')
    legend = plt.legend(fontsize = 'x-large')
#     plt.savefig('ROC_curve.png')
    plt.show()
    plt.plot(r,p,color='darkorange', label='Precision recall curve') 
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    legend=plt.legend(fontsize='x-large')
#     plt.savefig('Precision_Recall.png')
    plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 256, 256, 6)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 256, 256, 64)      3520
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 256, 256, 64)      256
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 256, 256, 64)      36928
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 256, 256, 64)      256
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 128, 128, 128)     73856
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 128, 128, 128)     512
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 128, 128, 128)     147584
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 128, 128, 128)     512
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 64, 64, 256)       295168
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 64, 64, 256)       1024
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 64, 64, 256)       590080
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 64, 64, 256)       1024
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 32, 32, 512)       1180160
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 32, 32, 512)       2048
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 32, 32, 512)       2359808
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 32, 32, 512)       2048
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32, 32, 512)       0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 16, 16, 1024)      4719616
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 16, 16, 1024)      4096
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 16, 16, 1024)      9438208
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 16, 16, 1024)      4096
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 8, 8, 1024)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 8, 8, 512)         4719104
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 4, 4, 256)         1179904
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 4096)              16384
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4096)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 4096)              16384
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 4096)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1024)              4195328
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 65,511,681
# Trainable params: 65,482,241
# Non-trainable params: 29,440
# _________________________________________________________________
# y_hat mean:0.243630 median:0.204593
# Sensitive TP/(TP+FN) : 0.590000
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59       100
#            1       0.59      0.59      0.59       100
#
#    micro avg       0.59      0.59      0.59       200
#    macro avg       0.59      0.59      0.59       200
# weighted avg       0.59      0.59      0.59       200
#
# y_hat mean:0.268742 median:0.244196
# Sensitive TP/(TP+FN) : 0.640000
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64       100
#            1       0.64      0.64      0.64       100
#
#    micro avg       0.64      0.64      0.64       200
#    macro avg       0.64      0.64      0.64       200
# weighted avg       0.64      0.64      0.64       200
#
# y_hat mean:0.251251 median:0.204620
# Sensitive TP/(TP+FN) : 0.600000
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60       100
#            1       0.60      0.60      0.60       100
#
#    micro avg       0.60      0.60      0.60       200
#    macro avg       0.60      0.60      0.60       200
# weighted avg       0.60      0.60      0.60       200
#
# y_hat mean:0.259729 median:0.229694
# Sensitive TP/(TP+FN) : 0.670000
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67       100
#            1       0.67      0.67      0.67       100
#
#    micro avg       0.67      0.67      0.67       200
#    macro avg       0.67      0.67      0.67       200
# weighted avg       0.67      0.67      0.67       200
#
# y_hat mean:0.271973 median:0.237580
# Sensitive TP/(TP+FN) : 0.560000
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56       100
#            1       0.56      0.56      0.56       100
#
#    micro avg       0.56      0.56      0.56       200
#    macro avg       0.56      0.56      0.56       200
# weighted avg       0.56      0.56      0.56       200
# y_hat mean:0.261210 median:0.207823
# Sensitive TP/(TP+FN) : 0.580000
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58       100
#            1       0.58      0.58      0.58       100
#
#    micro avg       0.58      0.58      0.58       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.58      0.58      0.58       200
#
# y_hat mean:0.275611 median:0.260039
# Sensitive TP/(TP+FN) : 0.620000
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62       100
#            1       0.62      0.62      0.62       100
#
#    micro avg       0.62      0.62      0.62       200
#    macro avg       0.62      0.62      0.62       200
# weighted avg       0.62      0.62      0.62       200
#
# y_hat mean:0.241895 median:0.183500
# Sensitive TP/(TP+FN) : 0.650000
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65       100
#            1       0.65      0.65      0.65       100
#
#    micro avg       0.65      0.65      0.65       200
#    macro avg       0.65      0.65      0.65       200
# weighted avg       0.65      0.65      0.65       200
#
# y_hat mean:0.255297 median:0.190789
# Sensitive TP/(TP+FN) : 0.640000
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64       100
#            1       0.64      0.64      0.64       100
#
#    micro avg       0.64      0.64      0.64       200
#    macro avg       0.64      0.64      0.64       200
# weighted avg       0.64      0.64      0.64       200
#
# y_hat mean:0.273351 median:0.223004
# Sensitive TP/(TP+FN) : 0.610000
#               precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       100
#            1       0.61      0.61      0.61       100
#
#    micro avg       0.61      0.61      0.61       200
#    macro avg       0.61      0.61      0.61       200
# weighted avg       0.61      0.61      0.61       200
#
# y_hat mean:0.288595 median:0.288341
# Sensitive TP/(TP+FN) : 0.670000
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67       100
#            1       0.67      0.67      0.67       100
#
#    micro avg       0.67      0.67      0.67       200
#    macro avg       0.67      0.67      0.67       200
# weighted avg       0.67      0.67      0.67       200
#
# y_hat mean:0.266892 median:0.253303
# Sensitive TP/(TP+FN) : 0.620000
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62       100
#            1       0.62      0.62      0.62       100
#
#    micro avg       0.62      0.62      0.62       200
#    macro avg       0.62      0.62      0.62       200
# weighted avg       0.62      0.62      0.62       200
#
# y_hat mean:0.246036 median:0.208405
# Sensitive TP/(TP+FN) : 0.640000
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64       100
#            1       0.64      0.64      0.64       100
#
#    micro avg       0.64      0.64      0.64       200
#    macro avg       0.64      0.64      0.64       200
# weighted avg       0.64      0.64      0.64       200
#
# y_hat mean:0.236195 median:0.202123
# Sensitive TP/(TP+FN) : 0.700000
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70       100
#            1       0.70      0.70      0.70       100
#
#    micro avg       0.70      0.70      0.70       200
#    macro avg       0.70      0.70      0.70       200
# weighted avg       0.70      0.70      0.70       200
#
# y_hat mean:0.266264 median:0.222471
# Sensitive TP/(TP+FN) : 0.660000
#               precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66       100
#            1       0.66      0.66      0.66       100
#
#    micro avg       0.66      0.66      0.66       200
#    macro avg       0.66      0.66      0.66       200
# weighted avg       0.66      0.66      0.66       200
#
# y_hat mean:0.261983 median:0.238024
# Sensitive TP/(TP+FN) : 0.610000
#               precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       100
#            1       0.61      0.61      0.61       100
#
#    micro avg       0.61      0.61      0.61       200
#    macro avg       0.61      0.61      0.61       200
# weighted avg       0.61      0.61      0.61       200
#
# y_hat mean:0.259371 median:0.231547
# Sensitive TP/(TP+FN) : 0.680000
#               precision    recall  f1-score   support
#
#            0       0.68      0.68      0.68       100
#            1       0.68      0.68      0.68       100
#
#    micro avg       0.68      0.68      0.68       200
#    macro avg       0.68      0.68      0.68       200
# weighted avg       0.68      0.68      0.68       200
#
# y_hat mean:0.240092 median:0.178797
# Sensitive TP/(TP+FN) : 0.630000
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63       100
#            1       0.63      0.63      0.63       100
#
#    micro avg       0.63      0.63      0.63       200
#    macro avg       0.63      0.63      0.63       200
# weighted avg       0.63      0.63      0.63       200
#
# y_hat mean:0.262044 median:0.230208
# Sensitive TP/(TP+FN) : 0.590000
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59       100
#            1       0.59      0.59      0.59       100
#
#    micro avg       0.59      0.59      0.59       200
#    macro avg       0.59      0.59      0.59       200
# weighted avg       0.59      0.59      0.59       200
#
# y_hat mean:0.257714 median:0.220633
# Sensitive TP/(TP+FN) : 0.660000
#               precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66       100
#            1       0.66      0.66      0.66       100
#
#    micro avg       0.66      0.66      0.66       200
#    macro avg       0.66      0.66      0.66       200
# weighted avg       0.66      0.66      0.66       200
#
# y_hat mean:0.273561 median:0.246719
# Sensitive TP/(TP+FN) : 0.610000
#               precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       100
#            1       0.61      0.61      0.61       100
#
#    micro avg       0.61      0.61      0.61       200
#    macro avg       0.61      0.61      0.61       200
# weighted avg       0.61      0.61      0.61       200
#
# y_hat mean:0.250040 median:0.211208
# Sensitive TP/(TP+FN) : 0.700000
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70       100
#            1       0.70      0.70      0.70       100
#
#    micro avg       0.70      0.70      0.70       200
#    macro avg       0.70      0.70      0.70       200
# weighted avg       0.70      0.70      0.70       200
#
# y_hat mean:0.257447 median:0.257181
# Sensitive TP/(TP+FN) : 0.610000
#               precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       100
#            1       0.61      0.61      0.61       100
#
#    micro avg       0.61      0.61      0.61       200
#    macro avg       0.61      0.61      0.61       200
# weighted avg       0.61      0.61      0.61       200
#
# y_hat mean:0.264735 median:0.244176
# Sensitive TP/(TP+FN) : 0.630000
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63       100
#            1       0.63      0.63      0.63       100
#
#    micro avg       0.63      0.63      0.63       200
#    macro avg       0.63      0.63      0.63       200
# weighted avg       0.63      0.63      0.63       200
#
# y_hat mean:0.250943 median:0.206915
# Sensitive TP/(TP+FN) : 0.670000
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67       100
#            1       0.67      0.67      0.67       100
#
#    micro avg       0.67      0.67      0.67       200
#    macro avg       0.67      0.67      0.67       200
# weighted avg       0.67      0.67      0.67       200
#
# y_hat mean:0.269062 median:0.240967
# Sensitive TP/(TP+FN) : 0.700000
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70       100
#            1       0.70      0.70      0.70       100
#
#    micro avg       0.70      0.70      0.70       200
#    macro avg       0.70      0.70      0.70       200
# weighted avg       0.70      0.70      0.70       200
# y_hat mean:0.261809 median:0.217912
# Sensitive TP/(TP+FN) : 0.640000
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64       100
#            1       0.64      0.64      0.64       100
#
#    micro avg       0.64      0.64      0.64       200
#    macro avg       0.64      0.64      0.64       200
# weighted avg       0.64      0.64      0.64       200
#
# y_hat mean:0.247609 median:0.177662
# Sensitive TP/(TP+FN) : 0.620000
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62       100
#            1       0.62      0.62      0.62       100
#
#    micro avg       0.62      0.62      0.62       200
#    macro avg       0.62      0.62      0.62       200
# weighted avg       0.62      0.62      0.62       200
#
# y_hat mean:0.274704 median:0.249643
# Sensitive TP/(TP+FN) : 0.580000
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58       100
#            1       0.58      0.58      0.58       100
#
#    micro avg       0.58      0.58      0.58       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.58      0.58      0.58       200
#
# y_hat mean:0.242102 median:0.217597
# Sensitive TP/(TP+FN) : 0.620000
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62       100
#            1       0.62      0.62      0.62       100
#
#    micro avg       0.62      0.62      0.62       200
#    macro avg       0.62      0.62      0.62       200
# weighted avg       0.62      0.62      0.62       200
#
# y_hat mean:0.271827 median:0.239027
# Sensitive TP/(TP+FN) : 0.603960
#               precision    recall  f1-score   support
#
#            0       0.60      0.61      0.60        99
#            1       0.61      0.60      0.61       101
#
#    micro avg       0.60      0.60      0.60       200
#    macro avg       0.60      0.61      0.60       200
# weighted avg       0.61      0.60      0.61       200
#
# y_hat mean:0.270753 median:0.237782
# Sensitive TP/(TP+FN) : 0.650000
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65       100
#            1       0.65      0.65      0.65       100
#
#    micro avg       0.65      0.65      0.65       200
#    macro avg       0.65      0.65      0.65       200
# weighted avg       0.65      0.65      0.65       200
#
# y_hat mean:0.279372 median:0.254124
# Sensitive TP/(TP+FN) : 0.590000
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59       100
#            1       0.59      0.59      0.59       100
#
#    micro avg       0.59      0.59      0.59       200
#    macro avg       0.59      0.59      0.59       200
# weighted avg       0.59      0.59      0.59       200
#
# y_hat mean:0.245857 median:0.223055
# Sensitive TP/(TP+FN) : 0.610000
#               precision    recall  f1-score   support
#
#            0       0.61      0.61      0.61       100
#            1       0.61      0.61      0.61       100
#
#    micro avg       0.61      0.61      0.61       200
#    macro avg       0.61      0.61      0.61       200
# weighted avg       0.61      0.61      0.61       200
#
# y_hat mean:0.244895 median:0.196148
# Sensitive TP/(TP+FN) : 0.630000
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63       100
#            1       0.63      0.63      0.63       100
#
#    micro avg       0.63      0.63      0.63       200
#    macro avg       0.63      0.63      0.63       200
# weighted avg       0.63      0.63      0.63       200
#
# y_hat mean:0.238867 median:0.189415
# Sensitive TP/(TP+FN) : 0.650000
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65       100
#            1       0.65      0.65      0.65       100
#
#    micro avg       0.65      0.65      0.65       200
#    macro avg       0.65      0.65      0.65       200
# weighted avg       0.65      0.65      0.65       200
#
# y_hat mean:0.261364 median:0.233581
# Sensitive TP/(TP+FN) : 0.680000
#               precision    recall  f1-score   support
#
#            0       0.68      0.68      0.68       100
#            1       0.68      0.68      0.68       100
#
#    micro avg       0.68      0.68      0.68       200
#    macro avg       0.68      0.68      0.68       200
# weighted avg       0.68      0.68      0.68       200
#
# y_hat mean:0.255870 median:0.227131
# Sensitive TP/(TP+FN) : 0.680000
#               precision    recall  f1-score   support
#
#            0       0.68      0.68      0.68       100
#            1       0.68      0.68      0.68       100
#
#    micro avg       0.68      0.68      0.68       200
#    macro avg       0.68      0.68      0.68       200
# weighted avg       0.68      0.68      0.68       200
#
# y_hat mean:0.267318 median:0.234985
# Sensitive TP/(TP+FN) : 0.670000
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67       100
#            1       0.67      0.67      0.67       100
#
#    micro avg       0.67      0.67      0.67       200
#    macro avg       0.67      0.67      0.67       200
# weighted avg       0.67      0.67      0.67       200
#
# y_hat mean:0.277997 median:0.275425
# Sensitive TP/(TP+FN) : 0.580000
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58       100
#            1       0.58      0.58      0.58       100
#
#    micro avg       0.58      0.58      0.58       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.58      0.58      0.58       200
#
# y_hat mean:0.258154 median:0.222329
# Sensitive TP/(TP+FN) : 0.620000
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62       100
#            1       0.62      0.62      0.62       100
#
#    micro avg       0.62      0.62      0.62       200
#    macro avg       0.62      0.62      0.62       200
# weighted avg       0.62      0.62      0.62       200
#
# y_hat mean:0.274921 median:0.234941
# Sensitive TP/(TP+FN) : 0.600000
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60       100
#            1       0.60      0.60      0.60       100
#
#    micro avg       0.60      0.60      0.60       200
#    macro avg       0.60      0.60      0.60       200
# weighted avg       0.60      0.60      0.60       200
#
# y_hat mean:0.257452 median:0.200498
# Sensitive TP/(TP+FN) : 0.640000
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64       100
#            1       0.64      0.64      0.64       100
#
#    micro avg       0.64      0.64      0.64       200
#    macro avg       0.64      0.64      0.64       200
# weighted avg       0.64      0.64      0.64       200
#
# y_hat mean:0.271302 median:0.255968
# Sensitive TP/(TP+FN) : 0.650000
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65       100
#            1       0.65      0.65      0.65       100
#
#    micro avg       0.65      0.65      0.65       200
#    macro avg       0.65      0.65      0.65       200
# weighted avg       0.65      0.65      0.65       200
#
# y_hat mean:0.246434 median:0.212383
# Sensitive TP/(TP+FN) : 0.590000
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59       100
#            1       0.59      0.59      0.59       100
#
#    micro avg       0.59      0.59      0.59       200
#    macro avg       0.59      0.59      0.59       200
# weighted avg       0.59      0.59      0.59       200
#
# y_hat mean:0.271456 median:0.254288
# Sensitive TP/(TP+FN) : 0.640000
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64       100
#            1       0.64      0.64      0.64       100
#
#    micro avg       0.64      0.64      0.64       200
#    macro avg       0.64      0.64      0.64       200
# weighted avg       0.64      0.64      0.64       200
#
# y_hat mean:0.276827 median:0.251496
# Sensitive TP/(TP+FN) : 0.690000
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69       100
#            1       0.69      0.69      0.69       100
#
#    micro avg       0.69      0.69      0.69       200
#    macro avg       0.69      0.69      0.69       200
# weighted avg       0.69      0.69      0.69       200
# y_hat mean:0.267721 median:0.228745
# Sensitive TP/(TP+FN) : 0.560000
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56       100
#            1       0.56      0.56      0.56       100
#
#    micro avg       0.56      0.56      0.56       200
#    macro avg       0.56      0.56      0.56       200
# weighted avg       0.56      0.56      0.56       200
#
# y_hat mean:0.270588 median:0.248913
# Sensitive TP/(TP+FN) : 0.630000
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63       100
#            1       0.63      0.63      0.63       100
#
#    micro avg       0.63      0.63      0.63       200
#    macro avg       0.63      0.63      0.63       200
# weighted avg       0.63      0.63      0.63       200
#
# y_hat mean:0.242622 median:0.220431
# Sensitive TP/(TP+FN) : 0.540000
#               precision    recall  f1-score   support
#
#            0       0.54      0.54      0.54       100
#            1       0.54      0.54      0.54       100
#
#    micro avg       0.54      0.54      0.54       200
#    macro avg       0.54      0.54      0.54       200
# weighted avg       0.54      0.54      0.54       200
#
# y_hat mean:0.237310 median:0.183406
# Sensitive TP/(TP+FN) : 0.580000
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58       100
#            1       0.58      0.58      0.58       100
#
#    micro avg       0.58      0.58      0.58       200
#    macro avg       0.58      0.58      0.58       200
# weighted avg       0.58      0.58      0.58       200
#
# (10200, 1)
# (10200, 1)
# y_hat mean:0.500000 median:0.500000
# Sensitive TP/(TP+FN) : 0.629092
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63      5099
#            1       0.63      0.63      0.63      5101
#
#    micro avg       0.63      0.63      0.63     10200
#    macro avg       0.63      0.63      0.63     10200
# weighted avg       0.63      0.63      0.63     10200

# %% [markdown]
# # ROC curve area = 0.629

# %%
    y_hat[y_hat < np.median(y_hat)] = 0
    y_hat[y_hat >= np.median(y_hat)] = 1
    TP, TN, FP, FN = Classify_Rate(y, y_hat)
    print("Sensitive TP/(TP+FN) : %f" %(TP / (TP + FN)))
    print(classification_report(y, y_hat))
